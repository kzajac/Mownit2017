# %% [markdown]
# ### DataFrames

# %% [markdown]
# - Zaawansowany pakiet do działania na tabelkach nxm danych
# - Podobne do pandas DataFrames w Pythonie albo data.frame w R
# - Specjalistyczne funkcje do statystyki
# - należy zaistalować pakiety:
#
# ```julia
# Pkg.add("DataFrames")
# Pkg.add("DataArrays")
# ```
#
# - DataFrame to rodzaj bazy danych in-memory
# - Składa się z kolumn, do których odwołujemy się używając symboli
# - Każda z kolumn jest typu DataArrays, który jest  parametryzowany typem przechowywanym w tej kolumnie
# - typ ten może być inny w każdej kolumnie (inaczej niż w dwuwymiarowych tablicach )
# - strona pakietu: https://github.com/JuliaData/DataFrames.jl
# - dokumentacja https://juliadata.github.io/DataFrames.jl/stable/

# %%
# wsparcie dla nieistniejących wartości - NA
# wartość NA, typ NAtype

using DataArrays 
using DataFrames
dv=@data([7,3,NA,5,42])
# Out:
# 5-element DataArrays.DataArray{Int64,1}:
#   7
#   3
#    NA
#   5
#  42

# %%
# funkcja drop NA czyli dropna()
sum(dropna(dv))
# Out:
# 57

# %%
using DataFrames
df1=DataFrame()
df1[:MojaKolumna]= 1:4
df1[:Col2]= [e,pi,sqrt(2), 42]
df1[:Col3]= [true,false, true, false]
show(df1)
# Out:
# 4×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 1           │ 2.71828 │ true  │
# │ 2   │ 2           │ 3.14159 │ false │
# │ 3   │ 3           │ 1.41421 │ true  │
# │ 4   │ 4           │ 42.0    │ false │

# %%
typeof(df1[:Col3])
# Out:
# DataArrays.DataArray{Bool,1}

# %%
# możemy też utworzyć DataFrame używając konstruktora
df2=DataFrame(MojaKolumna=1:10, 
    Col2=[e,pi, sqrt(2), 3, 4,e,pi, sqrt(2), 3, 4], 
    Col3=[true,true,false,true,false,true,true,false,true,false])
# Out:
# 10×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 1           │ 2.71828 │ true  │
# │ 2   │ 2           │ 3.14159 │ true  │
# │ 3   │ 3           │ 1.41421 │ false │
# │ 4   │ 4           │ 3.0     │ true  │
# │ 5   │ 5           │ 4.0     │ false │
# │ 6   │ 6           │ 2.71828 │ true  │
# │ 7   │ 7           │ 3.14159 │ true  │
# │ 8   │ 8           │ 1.41421 │ false │
# │ 9   │ 9           │ 3.0     │ true  │
# │ 10  │ 10          │ 4.0     │ false │

# %%
# można odwoływać się po indeksie
show(df2[2])
# Out:
# [2.71828, 3.14159, 1.41421, 3.0, 4.0, 2.71828, 3.14159, 1.41421, 3.0, 4.0]

# %%
# albo po symbolu kolumny
show(df2[:Col2])
# Out:
# [2.71828, 3.14159, 1.41421, 3.0, 4.0, 2.71828, 3.14159, 1.41421, 3.0, 4.0]

# %%
# wiersze lub podzbiory wierszy i kolumn uzyskujemy poprzez operator (:). Wynikiem jest nowy DataFrame
show(df2[3,:])
# Out:
# 1×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 3           │ 1.41421 │ false │

# %%
# drugi i trzeci wiersz
df2[2:3, :]
# Out:
# 2×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 2           │ 3.14159 │ true  │
# │ 2   │ 3           │ 1.41421 │ false │

# %%
# druga kolumna drugiego i trzeciego wiersza
df2[2:3, :Col2]
# Out:
# 2-element DataArrays.DataArray{Float64,1}:
#  3.14159
#  1.41421

# %%
# druga i trzecia kolumna drugiego i trzeciego wiersza
df2[2:3,[:Col2, :Col3]]
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ Col2    │ Col3  │
# ├─────┼─────────┼───────┤
# │ 1   │ 3.14159 │ true  │
# │ 2   │ 1.41421 │ false │

# %%
# pierwsze sześć wierszy
DataFrames.head(df2)
# Out:
# 6×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 1           │ 2.71828 │ true  │
# │ 2   │ 2           │ 3.14159 │ true  │
# │ 3   │ 3           │ 1.41421 │ false │
# │ 4   │ 4           │ 3.0     │ true  │
# │ 5   │ 5           │ 4.0     │ false │
# │ 6   │ 6           │ 2.71828 │ true  │

# %%
# ostatnie sześć wierszy
DataFrames.tail(df2)
# Out:
# 6×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3  │
# ├─────┼─────────────┼─────────┼───────┤
# │ 1   │ 5           │ 4.0     │ false │
# │ 2   │ 6           │ 2.71828 │ true  │
# │ 3   │ 7           │ 3.14159 │ true  │
# │ 4   │ 8           │ 1.41421 │ false │
# │ 5   │ 9           │ 3.0     │ true  │
# │ 6   │ 10          │ 4.0     │ false │

# %%
# nazwy kolumn
names(df2)
# Out:
# 3-element Array{Symbol,1}:
#  :MojaKolumna
#  :Col2
#  :Col3

# %%
# typy kolumn
eltypes(df2)
# Out:
# 3-element Array{Type,1}:
#  Int64
#  Float64
#  Bool

# %%
# podstawowe dane statystyczne o wartościach w kolumnie
describe(df2)
# Out:
# MojaKolumna
# Summary Stats:
# Mean:           5.500000
# Minimum:        1.000000
# 1st Quartile:   3.250000
# Median:         5.500000
# 3rd Quartile:   7.750000
# Maximum:        10.000000
# Length:         10
# Type:           Int64
# Number Missing: 0
# % Missing:      0.000000
#
# Col2
# Summary Stats:
# Mean:           2.854818
# Minimum:        1.414214
# 1st Quartile:   2.718282
# Median:         3.000000
# 3rd Quartile:   3.141593
# Maximum:        4.000000
# Length:         10
# Type:           Float64
# Number Missing: 0
# % Missing:      0.000000
#
# Col3
# Summary Stats:
# Mean:           0.600000
# Minimum:        0.000000
# 1st Quartile:   0.000000
# Median:         1.000000
# 3rd Quartile:   1.000000
# Maximum:        1.000000
# Length:         10
# Type:           Bool
# Number Missing: 0
# % Missing:      0.000000

# %%
mean(df2[:MojaKolumna])
# Out:
# 5.5

# %%
std(df2[:MojaKolumna])
# Out:
# 3.0276503540974917

# %%
# posortowane wartości w kolumnie Col2 (bez powtórzeń)
sort(unique(df2[:Col2]))
# Out:
# 5-element DataArrays.DataArray{Float64,1}:
#  1.41421
#  2.71828
#  3.0
#  3.14159
#  4.0

# %%
# zwraca tablice typu Boolean  w zależności od spełnianego warunku
df2[:Col3] .== true
# Out:
# 10-element DataArrays.DataArray{Bool,1}:
#   true
#   true
#  false
#   true
#  false
#   true
#   true
#  false
#   true
#  false

# %%
#Zwraca podzbiór dla wierszy spełniających warunek
df2[df2[:Col3] .== true, :]
# Out:
# 6×3 DataFrames.DataFrame
# │ Row │ MojaKolumna │ Col2    │ Col3 │
# ├─────┼─────────────┼─────────┼──────┤
# │ 1   │ 1           │ 2.71828 │ true │
# │ 2   │ 2           │ 3.14159 │ true │
# │ 3   │ 4           │ 3.0     │ true │
# │ 4   │ 6           │ 2.71828 │ true │
# │ 5   │ 7           │ 3.14159 │ true │
# │ 6   │ 9           │ 3.0     │ true │

# %%
# grupowanie wierszy (tutaj po wartosci Col3)
# ostatni argument to funkcja albo wyrażenie 
by(df2, :Col3, x->x)
# Out:
# 10×4 DataFrames.DataFrame
# │ Row │ Col3  │ MojaKolumna │ Col2    │ Col3_1 │
# ├─────┼───────┼─────────────┼─────────┼────────┤
# │ 1   │ false │ 3           │ 1.41421 │ false  │
# │ 2   │ false │ 5           │ 4.0     │ false  │
# │ 3   │ false │ 8           │ 1.41421 │ false  │
# │ 4   │ false │ 10          │ 4.0     │ false  │
# │ 5   │ true  │ 1           │ 2.71828 │ true   │
# │ 6   │ true  │ 2           │ 3.14159 │ true   │
# │ 7   │ true  │ 4           │ 3.0     │ true   │
# │ 8   │ true  │ 6           │ 2.71828 │ true   │
# │ 9   │ true  │ 7           │ 3.14159 │ true   │
# │ 10  │ true  │ 9           │ 3.0     │ true   │

# %%
# zliczanie ilosci wierszy pogrupowanych po wartosci kolumny Col3
by(df2, :Col3, x->size(x,1))
# Out:
# 2×2 DataFrames.DataFrame
# │ Row │ Col3  │ x1 │
# ├─────┼───────┼────┤
# │ 1   │ false │ 4  │
# │ 2   │ true  │ 6  │

# %%
using  DataFrames
df4=readtable("medical2.csv")
print("size is ", size(df4))
df4[1:20, 1:size(df4,2)]
# Out:
# size is (99, 7)
# 20×7 DataFrames.DataFrame
# │ Row │ Numer │ Płeć │ Wiek │ sBP   │ dBP   │ Drink │ BMI   │
# ├─────┼───────┼──────┼──────┼───────┼───────┼───────┼───────┤
# │ 1   │ 0     │ 1    │ 39   │ 106.0 │ 70.0  │ 0     │ 26.97 │
# │ 2   │ 1     │ 2    │ 46   │ 121.0 │ 81.0  │ 0     │ 28.73 │
# │ 3   │ 2     │ 1    │ 48   │ 127.5 │ 80.0  │ 1     │ 25.34 │
# │ 4   │ 3     │ 2    │ 61   │ 150.0 │ 95.0  │ 1     │ 28.58 │
# │ 5   │ 4     │ 2    │ 46   │ 130.0 │ 84.0  │ 1     │ 23.1  │
# │ 6   │ 5     │ 2    │ 43   │ 180.0 │ 110.0 │ 0     │ 30.3  │
# │ 7   │ 6     │ 2    │ 63   │ 138.0 │ 71.0  │ 0     │ 33.11 │
# │ 8   │ 7     │ 2    │ 45   │ 100.0 │ 71.0  │ 1     │ 21.68 │
# │ 9   │ 8     │ 1    │ 52   │ 141.5 │ 89.0  │ 0     │ 26.36 │
# │ 10  │ 9     │ 1    │ 43   │ 162.0 │ 107.0 │ 1     │ 23.61 │
# │ 11  │ 10    │ 2    │ 50   │ 133.0 │ 76.0  │ 0     │ 22.91 │
# │ 12  │ 11    │ 2    │ 43   │ 131.0 │ 88.0  │ 0     │ 27.64 │
# │ 13  │ 12    │ 1    │ 46   │ 142.0 │ 94.0  │ 1     │ 26.31 │
# │ 14  │ 13    │ 2    │ 41   │ 124.0 │ 88.0  │ 0     │ 31.31 │
# │ 15  │ 14    │ 2    │ 39   │ 114.0 │ 64.0  │ 1     │ 22.35 │
# │ 16  │ 15    │ 2    │ 38   │ 140.0 │ 90.0  │ 1     │ 21.35 │
# │ 17  │ 16    │ 1    │ 48   │ 138.0 │ 90.0  │ 1     │ 22.37 │
# │ 18  │ 17    │ 2    │ 46   │ 112.0 │ 78.0  │ 1     │ 23.38 │
# │ 19  │ 18    │ 2    │ 38   │ 122.0 │ 84.5  │ 1     │ 23.24 │
# │ 20  │ 19    │ 1    │ 41   │ 139.0 │ 88.0  │ 0     │ 26.88 │

# %%
df5=by(df4, :Wiek, df->DataFrame(Średnia_sBP=mean(df[:sBP]), Odchylenie_sBP=std(df[:sBP])))
# Out:
# 26×3 DataFrames.DataFrame
# │ Row │ Wiek │ Średnia_sBP │ Odchylenie_sBP │
# ├─────┼──────┼─────────────┼────────────────┤
# │ 1   │ 35   │ 132.5       │ 0.707107       │
# │ 2   │ 36   │ 107.0       │ 5.22813        │
# │ 3   │ 37   │ 125.0       │ 0.707107       │
# │ 4   │ 38   │ 131.5       │ 10.4083        │
# │ 5   │ 39   │ 110.5       │ 4.65475        │
# │ 6   │ 40   │ 125.5       │ 0.707107       │
# │ 7   │ 41   │ 128.833     │ 8.32867        │
# │ 8   │ 42   │ 131.0       │ 25.9872        │
# │ 9   │ 43   │ 138.5       │ 25.5556        │
# │ 10  │ 44   │ 138.0       │ 0.707107       │
# │ 11  │ 45   │ 100.5       │ 0.707107       │
# ⋮
# │ 15  │ 49   │ 96.5        │ 0.707107       │
# │ 16  │ 50   │ 133.5       │ 0.707107       │
# │ 17  │ 52   │ 146.4       │ 9.67758        │
# │ 18  │ 53   │ 206.5       │ 0.707107       │
# │ 19  │ 54   │ 140.0       │ 8.67948        │
# │ 20  │ 56   │ 154.0       │ 0.707107       │
# │ 21  │ 59   │ 150.5       │ 0.707107       │
# │ 22  │ 60   │ 120.5       │ 11.5614        │
# │ 23  │ 61   │ 155.833     │ 21.867         │
# │ 24  │ 62   │ 125.5       │ 0.707107       │
# │ 25  │ 63   │ 138.5       │ 0.707107       │
# │ 26  │ 65   │ 180.0       │ 0.707107       │

# %%
# to samo, za pomocą bloku 'do'
by(df4, :Wiek) do df
   DataFrame(m = mean(df[:sBP]), s = std(df[:sBP]))
end
# Out:
# 26×3 DataFrames.DataFrame
# │ Row │ Wiek │ m       │ s        │
# ├─────┼──────┼─────────┼──────────┤
# │ 1   │ 35   │ 132.5   │ 0.707107 │
# │ 2   │ 36   │ 107.0   │ 5.22813  │
# │ 3   │ 37   │ 125.0   │ 0.707107 │
# │ 4   │ 38   │ 131.5   │ 10.4083  │
# │ 5   │ 39   │ 110.5   │ 4.65475  │
# │ 6   │ 40   │ 125.5   │ 0.707107 │
# │ 7   │ 41   │ 128.833 │ 8.32867  │
# │ 8   │ 42   │ 131.0   │ 25.9872  │
# │ 9   │ 43   │ 138.5   │ 25.5556  │
# │ 10  │ 44   │ 138.0   │ 0.707107 │
# │ 11  │ 45   │ 100.5   │ 0.707107 │
# ⋮
# │ 15  │ 49   │ 96.5    │ 0.707107 │
# │ 16  │ 50   │ 133.5   │ 0.707107 │
# │ 17  │ 52   │ 146.4   │ 9.67758  │
# │ 18  │ 53   │ 206.5   │ 0.707107 │
# │ 19  │ 54   │ 140.0   │ 8.67948  │
# │ 20  │ 56   │ 154.0   │ 0.707107 │
# │ 21  │ 59   │ 150.5   │ 0.707107 │
# │ 22  │ 60   │ 120.5   │ 11.5614  │
# │ 23  │ 61   │ 155.833 │ 21.867   │
# │ 24  │ 62   │ 125.5   │ 0.707107 │
# │ 25  │ 63   │ 138.5   │ 0.707107 │
# │ 26  │ 65   │ 180.0   │ 0.707107 │

# %%
# funkcja aggregate
aggregate(df4, :Płeć, [sum, mean])
# Out:
# 2×13 DataFrames.DataFrame
# │ Row │ Płeć │ Numer_sum │ Numer_mean │ Wiek_sum │ Wiek_mean │ sBP_sum │
# ├─────┼──────┼───────────┼────────────┼──────────┼───────────┼─────────┤
# │ 1   │ 1    │ 2179      │ 50.6744    │ 1994     │ 46.3721   │ 5653.0  │
# │ 2   │ 2    │ 2672      │ 47.7143    │ 2746     │ 49.0357   │ 7627.0  │
#
# │ Row │ sBP_mean │ dBP_sum │ dBP_mean │ Drink_sum │ Drink_mean │ BMI_sum │
# ├─────┼──────────┼─────────┼──────────┼───────────┼────────────┼─────────┤
# │ 1   │ 131.465  │ 3679.5  │ 85.5698  │ 23        │ 0.534884   │ 1163.25 │
# │ 2   │ 136.196  │ 4778.0  │ 85.3214  │ 24        │ 0.428571   │ 1499.58 │
#
# │ Row │ BMI_mean │
# ├─────┼──────────┤
# │ 1   │ 27.0523  │
# │ 2   │ 26.7782  │

# %%
# funkcja wykonywana na każdym elemencie kolumny
df4[:Płeć]= ifelse.(df4[:Płeć].==1, "M", "K")
df4[:Drink]= ifelse.(df4[:Drink].==1, "T", "N")
df4[1:3, 1:size(df4,2)]
# Out:
# 3×7 DataFrames.DataFrame
# │ Row │ Numer │ Płeć │ Wiek │ sBP   │ dBP  │ Drink │ BMI   │
# ├─────┼───────┼──────┼──────┼───────┼──────┼───────┼───────┤
# │ 1   │ 0     │ "M"  │ 39   │ 106.0 │ 70.0 │ "N"   │ 26.97 │
# │ 2   │ 1     │ "K"  │ 46   │ 121.0 │ 81.0 │ "N"   │ 28.73 │
# │ 3   │ 2     │ "M"  │ 48   │ 127.5 │ 80.0 │ "T"   │ 25.34 │

# %% [markdown]
# ### Graficzna reprezentacja DataFrames
#
# Do wyświetlania danych statystycznych dobrym wyborem jest pakiet Gadfly
#
# ```julia
# Pkg.add("Gadfly")
# ```
# W razie ostrzeżeń o użyciu przestarzałego kodu spróbować:
# ```julia
# Pkg.update()
# ```
#
# - koncepcja wzięta z pakietu ggplot2 dla języka R
# - bazuje na książce Leland Wilkinson's "The Grammar of Graphics".
# - http://gadflyjl.org/stable/index.html

# %%
# wykres skórczowego ciśnienia krwi - systolic blood preassure (sBP)
# dla pierwszych 50 wierszy
# w zależności od wieku
# z podziałem wg płci
# 
using Gadfly
set_default_plot_size(20cm, 12cm)
df6=readtable("medical2.csv")
df6[:Płeć]= ifelse.(df6[:Płeć].==1, "Mężczyźni", "Kobiety")


plot(df6[1:50,:], x="Wiek", y="sBP", color="Płeć")
# Out:
# Plot(...)

# %%
plot(df5,x=:Wiek, y=:Średnia_sBP, ymin=df5[:Średnia_sBP]-df5[:Odchylenie_sBP], ymax=df5[:Średnia_sBP]+df5[:Odchylenie_sBP],
     Geom.point, Geom.errorbar)
# Out:
# Plot(...)

# %%
# kilka zależności na jednym wykresie:
#http://gadflyjl.org/stable/man/layers.html
plot(layer(x=rand(10), y=rand(10), Geom.point),
     layer(x=rand(10), y=rand(10), Geom.line))
# Out:
# Plot(...)

# %%
# układanie wykresów w "tabelki" wykresów

p1 = plot(x=[1,2,3], y=[4,5,6])
p2 = plot(x=[1,2,3], y=[6,7,8])
vstack(p1,p2)

p3 = plot(x=[5,7,8], y=[8,9,10])
p4 = plot(x=[5,7,8], y=[10,11,12])

# to jest to samo
vstack(hstack(p1,p2),hstack(p3,p4))
gridstack([p1 p2; p3 p4])
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Nullable{Compose.UnitBox}(), Nullable{Compose.Rotation}(), Nullable{Compose.Mirror}(), List([Compose.Table(Array{Compose.Context,1}[Compose.Context[Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), #NULL, #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}},Tuple{Measures.Add{Measures.Add{Measures.Length{:w,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}},Measures.Add{Measures.Add{Measures.Length{:h,Float64},Measures.Length{:mm,Float64}},Measures.Length{:mm,Float64}}}}((5.0mm, 5.0mm), (1.0w + -5.0mm + -5.0mm, 1.0h + -5.0mm + -5.0mm)), #NULL, #NULL, #NULL, List([Compose.Table(Array{Compose.Context,1}[Compose.Context[Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(1.0, 6.0, 2.0, -2.0, 0.0mm, 0.0mm, 2.0mm, 2.0mm), #NULL, #NULL, List([Compose.AdhocContainerPromise(Gadfly.Guide.#74, 0, false, false, nothing, nothing)]), List([]), List([]), 0, false, false, false, false, 5.80583, 7.61167, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(1.0, 6.0, 2.0, -2.0, 0.0mm, 0.0mm, 2.0mm, 2.0mm), #NULL, #NULL, List([Compose.AdhocContainerPromise(Gadfly.Guide.#75, 0, false, false, nothing, nothing)]), List([]), List([]), 0, false, false, false, false, 7.61167, 5.80583, 0.0, Symbol(""))] Compose.Context[Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(1.0, 6.0, 2.0, -2.0, 0.0mm, 0.0mm, 2.0mm, 2.0mm), #NULL, #NULL, List([Compose.AdhocContainerPromise(Gadfly.Guide.#54, 0, false, false, nothing, nothing)]), List([]), List([]), 0, false, false, false, false, 6.02, 13.3667, 3.0, Symbol(""))] Compose.Context[Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(1.0, 6.0, 2.0, -2.0, 2.0mm, 2.0mm, 2.0mm, 2.0mm), #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), #NULL, #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64,Float64,Float64,Float64}(1.0, 6.0, 2.0, -2.0, 2.0mm, 2.0mm, 2.0mm, 2.0mm), #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), #NULL, #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), #NULL, #NULL, #NULL, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, ...
